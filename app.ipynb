# %%
# Ajoutez le chemin au PYTHONPATH
import sys
sys.path.append('/workspaces/DangVan')

# Maintenant importez
import versDV as dv

# %%
# Utilisation
tens = dv.genereTens(100, 2*dv.pi, 0.01, 1)
result = dv.amplitudeTangMax(tens[0])
points = dv.nuage(100, 2*dv.pi, 0.01, 1)
dv.traceNuage(points)

# %%
# Utilisation
tens = dv.genereTensOrt(100, 2*dv.pi, 0.01, 1)
result = dv.amplitudeTangMax(tens[0])
points = dv.nuage(100, 2*dv.pi, 0.01, 1)
dv.traceNuage(points)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1367515582.py in <cell line: 0>()
#       1 # Utilisation
# ----> 2 tens = dv.genereTensOrt(100, 2*dv.pi, 0.01, 1)
#       3 result = dv.amplitudeTangMax(tens[0])
#       4 points = dv.nuage(100, 2*dv.pi, 0.01, 1)
#       5 dv.traceNuage(points)
#
# AttributeError: module 'versDV' has no attribute 'genereTensOrt'
