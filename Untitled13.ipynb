# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *

# %%
def normale(theta,phi):
    # retourne le vecteur unitaire définit par (cos(theta)*sin(phi),sin(theta)*sin(phi),cos(phi))
    vN = np.array([cos(theta)*sin(phi),sin(theta)*sin(phi),cos(phi)])
    return vN.T

# %%
def tens_to_mat(liste):
    if isinstance(liste,list):
        liste = np.array(liste)
    res = np.array([[liste[0],liste[3],liste[4]],
                    [liste[3],liste[1],liste[5]],
                    [liste[4],liste[5],liste[2]]])
    return res

# %%
def contTang(tens,vN):
    # calcul le vecteur contrainte tangentiell sur une facette de normale vN
    M = tens_to_mat(tens)# vecteur contrainte
    cont = M@vN# contrainte normale
 
    cN = cont@vN
    contT = cont-cN*vN
    return contT

# %%
def hydro(tens,instant):
    # cette fonction doit retourner la pression hydrostatique associée à ce tenseur (c'est pour un instant du cycle !)
    p = (tens[instant][0]+tens[instant][1]+tens[instant][2])/3
    return p

# %%
tens = genereTens(100,2*pi,0.01,1)
hydro(tens,0)
vN = normale(pi/4,pi/4)
resultat = contTang(tens[0],vN)
print(resultat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tens = genereTens(100,2*pi,0.01,1)
#       2 hydro(tens,0)
#       3 vN = normale(pi/4,pi/4)
#
# NameError: name 'genereTens' is not defined

# %%
def genereTens(sigma1,omega,pasTemps,fin):
  tens = np.array([sigma1,0,0,0,0,0])
  for i in range(int(fin/pasTemps)):
    t = i+1 * pasTemps
    ligne = np.array([sigma1*cos(omega*t),0,0,0,0,0])
    tens = np.vstack((tens, ligne))
    # omega est la pulsation, vous pouvez choisir 2*pi par exemple
    # sigma1 est fixe, par exemple 100 MPa
    # cette fonction doit générer une matrice de 6 colonnes, chaque ligne étant le tenseur à un instant du cycle, et de la forme [sigma1*cos(omega*t),0,0,0,0,0]
  return tens

# %%
a=np.array([1,0,0])
a.transpose()
# Out:
# array([1, 0, 0])

# %%
genereTens(100,2*pi,0.01,1)
# Out:
# array([[100.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [ 99.80267284,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ]])

# %%
def amplitudeTangMax(tens,instant):
    # cette fonction doit retourner pour UN instant une liste de deux éléments : le premier élément est la valeur max_n (norme de contTang) et le deuxième les angles du plan associés
    # il faut balayer les facette !
    maxi = 0
    theta = 0
    planMax = [0,0]
    phi = 0
    pasTheta = pi/180
    pasPhi = pi/180
    vect_norm = normale(theta,phi)
    for i in range(180+1):
        theta = i*pasTheta
        for j in range(180+1):
            phi = j*pasPhi
            # on construit le vecteur normal
            vect_norm = normale(theta,phi)
            # on calcule la contrainte tangentielle
            contT = contTang(tens[instant],vect_norm)
            # on calcule sa norme
            norme = np.linalg.norm(contT)
            # si elle est plus grande que maxi, elle devient maxi
            if norme > maxi:
                maxi = norme
                planMax = [theta,phi]
            #on actualise planMax
    # on retourne [maxi,planMax]
    return [maxi,planMax]

# %%
def nuage(sigma1,omega,pasTemps,fin):
  points = np.array([0,0])
  tensTot = genereTens(sigma1,omega,pasTemps,fin)
  for t in range(int(fin/pasTemps)):
    tens = tensTot[t]
    cisMax = amplitudeTangMax(tens,t)[0]
    hydros = hydro(tens,t)
    ligne = np.array([cisMax,hydros])
    points = np.vstack((points, ligne))
  return points

# %%
nuage(100,2*pi,0.01,1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 nuage(100,2*pi,0.01,1)
#
# Cell In[50], line 6, in nuage(sigma1, omega, pasTemps, fin)
#       4 for t in range(int(fin/pasTemps)):
#       5   tens = tensTot[t]
# ----> 6   cisMax = amplitudeTangMax(tens,t)[0]
#       7   hydros = hydro(tens,t)
#       8   ligne = np.array([cisMax,hydros])
#
# Cell In[49], line 18, in amplitudeTangMax(tens, instant)
#      16 vect_norm = normale(theta,phi)
#      17 # on calcule la contrainte tangentielle
# ---> 18 contT = contTang(tens[instant],vect_norm)
#      19 # on calcule sa norme
#      20 norme = np.linalg.norm(contT)
#
# Cell In[45], line 3, in contTang(tens, vN)
#       1 def contTang(tens,vN):
#       2     # calcul le vecteur contrainte tangentiell sur une facette de normale vN
# ----> 3     M = tens_to_mat(tens)# vecteur contrainte
#       4     cont = M@vN# contrainte normale
#       6     cN = cont@vN
#
# Cell In[41], line 4, in tens_to_mat(liste)
#       2 if isinstance(liste,list):
#       3     liste = np.array(liste)
# ----> 4 res = np.array([[liste[0],liste[3],liste[4]],
#       5                 [liste[3],liste[1],liste[5]],
#       6                 [liste[4],liste[5],liste[2]]])
#       7 return res
#
# IndexError: invalid index to scalar variable.

# %%
def traceNuage(points):
  plt.scatter(points[:, 0], points[:, 1])
  plt.xlabel("amplitude de cisaillement max")
  plt.ylabel("pression hydrostatique")
  plt.title("Nuage de points")
  plt.show()

# %%
points = np.array([[0,1],[1,2],[3,4],[8,4]])
traceNuage(points)

# %%
tens = np.array([100,0,0,0,0,0])
vN = np.array([1/sqrt(2), 1/sqrt(2),0])
resultat = contTang(tens,vN)
print(resultat)


# générer la matrice de 6 colonnes et Ntemps instants
# construire la liste des points [amplitude de cisaillement max, pression hydrostatique] (point correspondant chacun à un instant)

# utilisation de matplotlib : liste des abscisses, liste des ordonnées, puis tracé
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 tens = np.array([100,0,0,0,0,0])
#       2 vN = np.array([1/sqrt(2), 1/sqrt(2),0])
# ----> 3 resultat = contTang(tens,vN)
#       4 print(resultat)
#       7 # générer la matrice de 6 colonnes et Ntemps instants
#       8 # construire la liste des points [amplitude de cisaillement max, pression hydrostatique] (point correspondant chacun à un instant)
#       9
#      10 # utilisation de matplotlib : liste des abscisses, liste des ordonnées, puis tracé
#
# Cell In[8], line 3, in contTang(tens, vN)
#       1 def contTang(tens,vN):
#       2     # calcul le vecteur contrainte tangentiell sur une facette de normale vN
# ----> 3     M = tens_to_mat(tens)# vecteur contrainte
#       4     cont = M@vN# contrainte normale
#       5     # contT = cont.transpose()
#
# Cell In[7], line 2, in tens_to_mat(liste)
#       1 def tens_to_mat(liste):
# ----> 2     res = np.array([liste[0],liste[3],liste[4]],
#       3                     [liste[3],liste[1],liste[5]],
#       4                     [liste[4],liste[5],liste[2]])
#       7     return res
#
# TypeError: array() takes from 1 to 2 positional arguments but 3 were given
